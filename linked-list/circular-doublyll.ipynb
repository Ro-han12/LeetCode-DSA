# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None
        self.prev = None

    def __str__(self):
        return str(self.value)

class CircularDoublyll:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
    def __str__(self):
        if self.head is None:
            return "Empty list"
        temp = self.head 
        res = ''
        while True:
            res += str(temp.value)
            temp = temp.next
            if temp == self.head:
                break
            res += ' <-> '
        return res
        
    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
            new_node.next = new_node
            new_node.prev = new_node
        else:
            self.tail.next = new_node
            self.head.prev = new_node
            new_node.next = self.head
            new_node.prev = self.tail
            self.tail = new_node
        self.length += 1
        
    def prepend(self,value):
        new_node=Node(value)
        curr=self.head
        if self.head is None:
            self.head=new_node
            self.tail=new_node
            new_node.next=new_node
            new_node.prev=new_node
        else:
            new_node.next=curr
            new_node.prev=self.tail
            curr.prev=new_node
            self.tail.next=new_node
            self.head=new_node
        self.length+=1
        
    def traversal(self):
        if self.head is None:
            return None
        curr=self.head
        while curr:
            print(curr.value)
            if curr.next == self.head:
                break
            curr=curr.next 
        return curr.value
    
    def rev_traversal(self):
        if self.head is None:
            return None
        curr=self.tail
        while curr:
            print(curr.value)
            curr=curr.prev 
            if curr == self.tail:
                break
    def search(self,value):
        if self.head is None:
            return None
        curr=self.head
        while curr: 
            if curr.value==value:
                return True
            curr=curr.next
            if curr.next == self.head:
                break
        return False
    
    def get(self,index):
        if index > self.length or index < -1:
            return 'IndexError'
        curr=self.head
        for _ in range(index):
            curr=curr.next
        return curr
    
    def set(self,index,value):
        if index > self.length or index < -1:
            return 'IndexError'
        curr=self.get(index)
        if curr:
            curr.value=value
            return True
        return False
        
            
        
    
cdll = CircularDoublyll()
cdll.append(23)
cdll.append(63)
print(cdll)
cdll.prepend(98)
print(cdll)
print("applying traversal method")
cdll.traversal()
print("applying reverse traversal method")
cdll.rev_traversal()
print("applying search method")
cdll.search(23)
print("applying get method")
cdll.get(0)
print(cdll)
print("applying SET method")
cdll.set(0,67)
cdll.set(2,697)
print(cdll)
# Out:
# 23 <-> 63
# 98 <-> 23 <-> 63
# applying traversal method
# 98
# 23
# 63
# applying reverse traversal method
# 63
# 23
# 98
# applying search method
# applying get method
# 98 <-> 23 <-> 63
# applying SET method
# 67 <-> 23 <-> 697
